# %%
import os
import time

from joblib import dump, load

import matplotlib.pyplot as plt
from IPython import display

from imageio import imread
import numpy as np 
import scipy

import theano.tensor as T
import lasagne.layers
from lasagne.nonlinearities import elu
import theano

from tqdm import tqdm_notebook

from nn_utils import build_UNet, iterate_minibatches
from train_data_preparation import prepare_data, extract_random_patches, extract_grid_patches
from sklearn.metrics import average_precision_score

# %%
run processing_functions.ipynb

# %%
patch_size = 64
base_n_filters = 32
nonlinearity = elu
batch_size = 128

# %%
carb_stacks = ['carb71', 'carb96558', 'carbRNF', 'SPE_carb10_58_box3']
soil_stacks = ['SoilAh-1', 'SoilB-2', 'TeTree_subset1', 'TiTree_subset2']
urna_stacks = ['Urna_22', 'Urna_30', 'Urna_34']

# %%
def create_predictor(weights_name):
    input_image = T.tensor4('input')
    target = T.matrix('output', dtype='int64')

    net = build_UNet(n_input_channels=1, 
                     BATCH_SIZE=None, 
                     num_output_classes=2,
                     pad='same', 
                     nonlinearity=nonlinearity,
                     input_dim=(patch_size, patch_size), 
                     base_n_filters=base_n_filters, 
                     do_dropout=True,
                     weights=load(weights_name))
    predictions = lasagne.layers.get_output(net['output_flattened'], input_image)
    get_predictions = theano.function([input_image], predictions)
    return get_predictions

# %%
def get_predictions(input_stack_path, output_stack_path, predictor, images_number=None):
    #input_stack = []
    output_stack = []
    results = []
    
    if images_number is None:
        images_number = len(os.listdir(input_stack_path))
        
    for i, (fgray, fbin) in enumerate(zip(sorted(os.listdir(input_stack_path)), 
                                          sorted(os.listdir(output_stack_path)))):
        input_img = imread(os.path.join(input_stack_path, fgray))
        #input_stack.append(input_img.reshape(input_img.shape + (1, )))

        output_img = imread(os.path.join(output_stack_path, fbin))
        output_stack.append(output_img.reshape(output_img.shape + (1, )))

        prediction = predict_image(input_img, predictor, patch_size, n_input_channels=1)
        prediction = prediction.reshape(prediction.shape + (1, ))
        results.append(prediction)
        if i > images_number:
            break
        if i % 100 == 0:
            print('Progress: {} of {} images'.format(i, images_number))

    #input_stack = np.concatenate(input_stack, axis=2)
    output_stack = np.concatenate(output_stack, axis=2)
    prediction = np.concatenate(results, axis=2)
    
    #return input_stack, output_stack, prediction
    return output_stack, prediction

# %%
def get_stacks(input_stack_path, output_stack_path):
    input_stack = []
    output_stack = []
        
    images_number = len(os.listdir(input_stack_path))
    for i, (fgray, fbin) in enumerate(zip(sorted(os.listdir(input_stack_path)), 
                                          sorted(os.listdir(output_stack_path)))):
        input_img = imread(os.path.join(input_stack_path, fgray))
        input_stack.append(input_img.reshape(input_img.shape + (1, )))

        output_img = imread(os.path.join(output_stack_path, fbin))
        output_stack.append(output_img.reshape(output_img.shape + (1, )))

        if i % 100 == 0:
            print('Progress: {} of {} images'.format(i, images_number))

    input_stack = np.concatenate(input_stack, axis=2)
    output_stack = np.concatenate(output_stack, axis=2)
    
    return input_stack, output_stack

# %%
def iou(prediction, target, threshold):
    rounded = np.where(prediction > threshold, 
                       np.ones_like(prediction, dtype=np.float32),
                       np.zeros_like(prediction, dtype=np.float32))
    return (rounded * target).sum() / (rounded + target - rounded * target).sum()

# %%
def logloss(prediction, target):
    eps = 1e-6
    prediction = np.where(np.abs(prediction) < eps, np.full(prediction.shape, eps, dtype=np.float32), prediction)
    prediction = np.where(np.abs(prediction - 1) < eps, np.full(prediction.shape, 1 - eps, dtype=np.float32), prediction)
    return -(target * np.log(prediction) + (1 - target) * np.log(1 - prediction)).mean()

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import average_precision_score

def accuracy(prediction, target, threshold):
    rounded = np.where(prediction > threshold, 
                       np.ones_like(prediction, dtype=np.float32),
                       np.zeros_like(prediction, dtype=np.float32))
    return (rounded == target).mean()

def precision(prediction, target, threshold):
    rounded = np.where(prediction > threshold, 
                       np.ones_like(prediction, dtype=np.float32),
                       np.zeros_like(prediction, dtype=np.float32))
    return precision_score(target.flatten(), rounded.flatten())

def recall(prediction, target, threshold):
    rounded = np.where(prediction > threshold, 
                       np.ones_like(prediction, dtype=np.float32),
                       np.zeros_like(prediction, dtype=np.float32))
    return recall_score(target.flatten(), rounded.flatten())

# %%
def metric_curve(prediction, output_stack, num_steps, metric):
    metrics = []
    
    left = 1 - np.logspace(-1, 0, num_steps / 2, base=2)[::-1][:-1]
    right = np.logspace(-1, 0, num_steps / 2, base=2)
    
    for x in np.concatenate([left, right]):
        metrics.append(metric(prediction, output_stack, x))
    return np.concatenate([left, right]), metrics

# %%
trained_stack_name = 'SoilB-2_Urna_22_carb96558'
weights_name = ''.join([trained_stack_name, '_weights/UNet_params_ep009.jbl'])
weights_path = os.path.join('../output_data/weights', weights_name)

# %%
# %%time
results = {}

predictor = create_predictor(weights_path)
predicting_stack_names = carb_stacks + soil_stacks + urna_stacks

for predicting_stack_name in predicting_stack_names:
    cresults = {}
    input_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'NLM')
    output_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'CAC')

    output_stack, prediction = get_predictions(input_stack_path, output_stack_path, predictor, images_number=250)
    output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)
    
    cresults['logloss'] = logloss(prediction, output_stack)
    cresults['PR-AUC'] = average_precision_score(output_stack.flatten(), prediction.flatten())
    cresults['iou'] = metric_curve(prediction, output_stack, 30, iou)
    cresults['accuracy'] = metric_curve(prediction, output_stack, 30, accuracy)
    cresults['precision'] = metric_curve(prediction, output_stack, 30, precision)
    cresults['recall'] = metric_curve(prediction, output_stack, 30, recall)
    
    print('Stack: {}\n   logloss: {}\n   PR-AUC: {}\n'
          .format(predicting_stack_name, cresults['logloss'], cresults['PR-AUC']))
    results[predicting_stack_name] = cresults
    dump(results, '../output_data/' + trained_stack_name + '.jbl')
#     storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
#     dump(prediction, os.path.join('../output_data', storing_path))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-5-2c89cbb5c458> in create_predictor(weights_name)
#      12                      do_dropout=True,
#      13                      weights=load(weights_name))
# ---> 14     predictions = lasagne.layers.get_output(net['output_flattened'], input_image)
#      15     get_predictions = theano.function([input_image], predictions)
#      16     return get_predictions
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/lasagne/layers/helper.py in get_output(layer_or_layers, inputs, **kwargs)
#     195                                  "mapping this layer to an input expression."
#     196                                  % layer)
# --> 197             all_outputs[layer] = layer.get_output_for(layer_inputs, **kwargs)
#     198             try:
#     199                 accepted_kwargs |= set(utils.inspect_kwargs(
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/lasagne/layers/noise.py in get_output_for(self, input, deterministic, **kwargs)
#     100                                    for a, s in enumerate(mask_shape))
#     101             mask = self._srng.binomial(mask_shape, p=retain_prob,
# --> 102                                        dtype=input.dtype)
#     103             if self.shared_axes:
#     104                 bcast = tuple(bool(s == 1) for s in mask_shape)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/sandbox/rng_mrg.py in binomial(self, size, n, p, ndim, dtype, nstreams, **kwargs)
#     899         if n == 1:
#     900             p = undefined_grad(as_tensor_variable(p))
# --> 901             x = self.uniform(size=size, nstreams=nstreams, **kwargs)
#     902             return cast(x < p, dtype)
#     903         else:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/sandbox/rng_mrg.py in uniform(self, size, low, high, ndim, dtype, nstreams, **kwargs)
#     870         if nstreams is None:
#     871             nstreams = self.n_streams(size)
# --> 872         rstates = self.get_substream_rstates(nstreams, dtype)
#     873
#     874         d = {}
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/configparser.py in res(*args, **kwargs)
#     115         def res(*args, **kwargs):
#     116             with self:
# --> 117                 return f(*args, **kwargs)
#     118         return res
#     119
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/sandbox/rng_mrg.py in get_substream_rstates(self, n_streams, dtype, inc_rstate)
#     777         # If multMatVect.dot_modulo isn't compiled, compile it.
#     778         if multMatVect.dot_modulo is None:
# --> 779             multMatVect(rval[0], A1p72, M1, A2p72, M2)
#     780
#     781         # This way of calling the Theano fct is done to bypass Theano overhead.
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/sandbox/rng_mrg.py in multMatVect(v, A, m1, B, m2)
#      60         o = DotModulo()(A_sym, s_sym, m_sym, A2_sym, s2_sym, m2_sym)
#      61         multMatVect.dot_modulo = function(
# ---> 62             [A_sym, s_sym, m_sym, A2_sym, s2_sym, m2_sym], o, profile=False)
#      63
#      64     # This way of calling the Theano fct is done to bypass Theano overhead.
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     return fn
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1839                   name=name)
#    1840         with theano.change_flags(compute_test_value="off"):
# -> 1841             fn = m.create(defaults)
#    1842     finally:
#    1843         t2 = time.time()
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/compile/function_module.py in create(self, input_storage, trustme, storage_map)
#    1713             theano.config.traceback.limit = theano.config.traceback.compile_limit
#    1714             _fn, _i, _o = self.linker.make_thunk(
# -> 1715                 input_storage=input_storage_lists, storage_map=storage_map)
#    1716         finally:
#    1717             theano.config.traceback.limit = limit_orig
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/link.py in make_thunk(self, input_storage, output_storage, storage_map)
#     697         return self.make_all(input_storage=input_storage,
#     698                              output_storage=output_storage,
# --> 699                              storage_map=storage_map)[:3]
#     700
#     701     def make_all(self, input_storage, output_storage):
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/vm.py in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1082                                                  compute_map,
#    1083                                                  [],
# -> 1084                                                  impl=impl))
#    1085                 linker_make_thunk_time[node] = time.time() - thunk_start
#    1086                 if not hasattr(thunks[-1], 'lazy'):
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     953             try:
#     954                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 955                                          no_recycling)
#     956             except (NotImplementedError, utils.MethodNotDefined):
#     957                 # We requested the c code, so don't catch the error.
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     856         _logger.debug('Trying CLinker.make_thunk')
#     857         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 858                                 output_storage=node_output_storage)
#     859         thunk, node_input_filters, node_output_filters = outputs
#     860
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cc.py in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1215         cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1216             input_storage, output_storage, storage_map,
# -> 1217             keep_lock=keep_lock)
#    1218
#    1219         res = _CThunk(cthunk, init_tasks, tasks, error_storage, module)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cc.py in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1155                                             output_storage,
#    1156                                             storage_map,
# -> 1157                                             keep_lock=keep_lock)
#    1158         return (thunk,
#    1159                 module,
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cc.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1617             for node in self.node_order:
#    1618                 node.op.prepare_node(node, storage_map, None, 'c')
# -> 1619             module = get_module_cache().module_from_key(
#    1620                 key=key, lnk=self, keep_lock=keep_lock)
#    1621
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cc.py in get_module_cache(init_args)
#      46
#      47     """
# ---> 48     return cmodule.get_module_cache(config.compiledir, init_args=init_args)
#      49
#      50
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cmodule.py in get_module_cache(dirname, init_args)
#    1570         init_args = {}
#    1571     if _module_cache is None:
# -> 1572         _module_cache = ModuleCache(dirname, **init_args)
#    1573         atexit.register(_module_cache._on_atexit)
#    1574     elif init_args:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cmodule.py in __init__(self, dirname, check_for_broken_eq, do_refresh)
#     686
#     687         if do_refresh:
# --> 688             self.refresh()
#     689
#     690     age_thresh_use = config.cmodule.age_thresh_use  # default 24 days
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/gof/cmodule.py in refresh(self, age_thresh_use, delete_if_problem, cleanup)
#     809                     try:
#     810                         with open(key_pkl, 'rb') as f:
# --> 811                             key_data = pickle.load(f)
#     812                     except EOFError:
#     813                         # Happened once... not sure why (would be worth
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/theano/scalar/basic.py in __setstate__(self, d)
#    4120         return rval
#    4121
# -> 4122     def __setstate__(self, d):
#    4123         self.__dict__.update(d)
#    4124         # We must call init to set fgraph and _impls again, as otherwise
#
# KeyboardInterrupt:

# %%
trained_stack_names = [
    'carb96558_SoilB-2', 
    'carb96558_Urna_22', 
    'SoilB-2_Urna_22', 
    'carb96558',
    'SoilB-2',
    'Urna_22',    
#     'SoilB-2_Urna_22_carb96558'
]

predicting_stack_names = carb_stacks + soil_stacks + urna_stacks
total_results = {}

for trained_stack_name in trained_stack_names:
    weights_name = ''.join([trained_stack_name, '_weights/UNet_params_ep009.jbl'])
    weights_path = os.path.join('../output_data/weights', weights_name)
    results = {}
    
    predictor = create_predictor(weights_path)

    for predicting_stack_name in predicting_stack_names:
        cresults = {}
        input_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'NLM')
        output_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'CAC')

        output_stack, prediction = get_predictions(input_stack_path, output_stack_path, predictor, images_number=250)
        output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)

        cresults['logloss'] = logloss(prediction, output_stack)
        cresults['PR-AUC'] = average_precision_score(output_stack.flatten(), prediction.flatten())
        cresults['iou'] = metric_curve(prediction, output_stack, 30, iou)
        cresults['accuracy'] = metric_curve(prediction, output_stack, 30, accuracy)
        cresults['precision'] = metric_curve(prediction, output_stack, 30, precision)
        cresults['recall'] = metric_curve(prediction, output_stack, 30, recall)

        print('Stack: {}\n   logloss: {}\n   PR-AUC: {}\n'
              .format(predicting_stack_name, cresults['logloss'], cresults['PR-AUC']))
        results[predicting_stack_name] = cresults
        dump(results, '../output_data/' + trained_stack_name + '.jbl')
    total_results[trained_stack_name] = results
dump(total_results, 'total_results.jbl')

# %%
# %%time
for predicting_stack_name in ['Urna_34']:
    input_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'NLM')
    output_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'CAC')

    input_stack, output_stack = get_stacks(input_stack_path, output_stack_path)
    output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)
# Out:
# Progress: 0 of 700 images
# Progress: 100 of 700 images
# Progress: 200 of 700 images
# Progress: 300 of 700 images
# Progress: 400 of 700 images
# Progress: 500 of 700 images
# Progress: 600 of 700 images
# CPU times: user 10.9 s, sys: 5.7 s, total: 16.6 s
# Wall time: 33.1 s

# %%
prediction = load('../output_data/SoilB-2_Urna_22_carb96558_on_Urna_34.jbl')

# %%
ciou = []
clogloss = []
caccuracy = []
cap = []

splitters = list(range(0, 701, 233))
for i in range(len(splitters) - 1):
    l = splitters[i]
    r = splitters[i + 1]
    ciou.append(iou(prediction[:, :, l:r], output_stack[:, :, l:r], 0.1))
    clogloss.append(logloss(prediction[:, :, l:r], output_stack[:, :, l:r]))
    caccuracy.append(accuracy(prediction[:, :, l:r], output_stack[:, :, l:r], 0.1))
    cap.append(average_precision_score(output_stack[:, :, l:r].flatten(), prediction[:, :, l:r].flatten()))
    
    print('Stack: {}\n   logloss: {}\n   iou: {}\n   accuracy: {}\n   PR-AUC: {}\n'
          .format(predicting_stack_name, clogloss[-1], ciou[-1], caccuracy[-1], cap[-1]))
# Out:
# Stack: Urna_34
#    logloss: 0.10292653739452362
#    iou: 0.9633175730705261
#    accuracy: 0.9679640185688009
#    PR-AUC: 0.9992194944146889
#
# Stack: Urna_34
#    logloss: 0.10529028624296188
#    iou: 0.9626685380935669
#    accuracy: 0.9674284663221512
#    PR-AUC: 0.9992092825340885
#
# Stack: Urna_34
#    logloss: 0.09907206892967224
#    iou: 0.9657343029975891
#    accuracy: 0.9696620741000263
#    PR-AUC: 0.9992470864383007

# %%
(clogloss - np.mean(clogloss)) / np.mean(clogloss)
# Out:
# array([ 0.00485122,  0.02792803, -0.03277918], dtype=float32)

# %%
# %%time

predicting_stack_name = 'carbRNF'
input_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'NLM')
output_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'CAC')

input_stack, output_stack, prediction = get_stacks(input_stack_path, output_stack_path, weights_path, images_number=None)

storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
dump((input_stack, output_stack, prediction), 
      os.path.join('../output_data', storing_path))
# Out:
# Progress: 0 of 700 images
# Progress: 100 of 700 images
# Progress: 200 of 700 images
# Progress: 300 of 700 images
# Progress: 400 of 700 images
# Progress: 500 of 700 images
# Progress: 600 of 700 images
# CPU times: user 8h 32min 27s, sys: 4h 16min 19s, total: 12h 48min 46s
# Wall time: 3h 28min 51s

# %%
# %%time

predicting_stack_name = 'SPE_carb10_58_box3'
input_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'NLM')
output_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'CAC')

input_stack, output_stack, prediction = get_stacks(input_stack_path, output_stack_path, weights_path, images_number=None)

storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
dump((input_stack, output_stack, prediction), 
      os.path.join('../output_data', storing_path))
# Out:
# Progress: 0 of 509 images
# Progress: 100 of 509 images
# Progress: 200 of 509 images
# Progress: 300 of 509 images
# Progress: 400 of 509 images
# Progress: 500 of 509 images
# CPU times: user 3h 33min 58s, sys: 2h 33s, total: 5h 34min 31s
# Wall time: 1h 18min 27s

# %%
# %%time

predicting_stack_name = 'SPE_carb10_63_box3'
input_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'NLM')
output_stack_path = os.path.join('../all_data/binary_data', predicting_stack_name, 'CAC')

input_stack, output_stack, prediction = get_stacks(input_stack_path, output_stack_path, weights_path, images_number=None)

storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
dump((input_stack, output_stack, prediction), 
      os.path.join('../output_data', storing_path))
# Out:
# Progress: 0 of 509 images
# Progress: 100 of 509 images
# Progress: 200 of 509 images
# Progress: 300 of 509 images
# Progress: 400 of 509 images
# Progress: 500 of 509 images
# CPU times: user 3h 27min 44s, sys: 1h 55min 7s, total: 5h 22min 52s
# Wall time: 1h 17min 22s

# %%
trained_stack_name = 'carb96558'
predicting_stack_name = 'SPE_carb10_58_box3'
storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
input_stack, output_stack, prediction = load(os.path.join('../output_data', storing_path))
output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)
x1, y1 = accuracy_curve(prediction, output_stack, 40)

binary = rounded = np.where(prediction > 0.1, 
                            np.ones_like(prediction, dtype=np.float32),
                            np.zeros_like(prediction, dtype=np.float32)).flatten()
p1, r1, _ = precision_recall_curve(output_stack.flatten(), prediction.flatten(), pos_label=1)

plt.step(r1, p1, color='b', alpha=0.2, where='post')
plt.fill_between(r1, p1, step='post', alpha=0.2, color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

ap1 = average_precision_score(output_stack.flatten(), binary)
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(ap1))


print('Integrated accuracy: {}'.format(scipy.integrate.simps(y1, x1)))
print('Precission: {}'.format(precision_score(output_stack.flatten(), binary)))
print('Recall: {}'.format(precision_score(output_stack.flatten(), binary)))
print('PR-auc: {}'.format(ap1))

plt.show()
# Out:
# Integrated accuracy: 0.976878006722599
# Precission: 0.9854681558591756
# Recall: 0.9854681558591756
# PR-auc: 0.9854667446507043

# %%
trained_stack_name = 'carb96558'
predicting_stack_name = 'carbRNF'
storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
input_stack, output_stack, prediction = load(os.path.join('../output_data', storing_path))
output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)
x2, y2 = accuracy_curve(prediction, output_stack, 40)

binary = rounded = np.where(prediction > 0.1, 
                            np.ones_like(prediction, dtype=np.float32),
                            np.zeros_like(prediction, dtype=np.float32)).flatten()
p2, r2, _ = precision_recall_curve(output_stack.flatten(), prediction.flatten(), pos_label=1)

plt.step(r2, p2, color='b', alpha=0.2, where='post')
plt.fill_between(r2, p2, step='post', alpha=0.2, color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

ap2 = average_precision_score(output_stack.flatten(), binary)
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(ap2))


print('Integrated accuracy: {}'.format(scipy.integrate.simps(y2, x2)))
print('Precission: {}'.format(precision_score(output_stack.flatten(), binary)))
print('Recall: {}'.format(precision_score(output_stack.flatten(), binary)))
print('PR-auc: {}'.format(ap2))

plt.show()
# Out:
# Integrated accuracy: 0.935935966003354
# Precission: 0.9416464825420011
# Recall: 0.9416464825420011
# PR-auc: 0.9415342263548329

# %%
trained_stack_name = 'carb96558'
predicting_stack_name = 'carb71'
storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
input_stack, output_stack, prediction = load(os.path.join('../output_data', storing_path))
output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)
x3, y3 = accuracy_curve(prediction, output_stack, 40)

binary = rounded = np.where(prediction > 0.1, 
                            np.ones_like(prediction, dtype=np.float32),
                            np.zeros_like(prediction, dtype=np.float32)).flatten()
p3, r3, _ = precision_recall_curve(output_stack.flatten(), prediction.flatten(), pos_label=1)

plt.step(r3, p3, color='b', alpha=0.2, where='post')
plt.fill_between(r3, p3, step='post', alpha=0.2, color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

ap3 = average_precision_score(output_stack.flatten(), binary)
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(ap3))


print('Integrated accuracy: {}'.format(scipy.integrate.simps(y3, x3)))
print('Precission: {}'.format(precision_score(output_stack.flatten(), binary)))
print('Recall: {}'.format(precision_score(output_stack.flatten(), binary)))
print('PR-auc: {}'.format(ap3))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-22-0128704a0c59> in <module>()
#      19 plt.xlim([0.0, 1.0])
#      20
# ---> 21 ap3 = average_precision_score(output_stack.flatten(), binary)
#      22 plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(ap3))
#      23
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/sklearn/metrics/ranking.py in average_precision_score(y_true, y_score, average, sample_weight)
#     197     return _average_binary_score(_binary_uninterpolated_average_precision,
#     198                                  y_true, y_score, average,
# --> 199                                  sample_weight=sample_weight)
#     200
#     201
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      73
#      74     if y_type == "binary":
# ---> 75         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      76
#      77     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/sklearn/metrics/ranking.py in _binary_uninterpolated_average_precision(y_true, y_score, sample_weight)
#     189             y_true, y_score, sample_weight=None):
#     190         precision, recall, thresholds = precision_recall_curve(
# --> 191             y_true, y_score, sample_weight=sample_weight)
#     192         # Return the step function integral
#     193         # The following works because the last entry of precision is
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/sklearn/metrics/ranking.py in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight)
#     439     fps, tps, thresholds = _binary_clf_curve(y_true, probas_pred,
#     440                                              pos_label=pos_label,
# --> 441                                              sample_weight=sample_weight)
#     442
#     443     precision = tps / (tps + fps)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/sklearn/metrics/ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     358
#     359     # accumulate the true positives with decreasing threshold
# --> 360     tps = stable_cumsum(y_true * weight)[threshold_idxs]
#     361     if sample_weight is not None:
#     362         fps = stable_cumsum(weight)[threshold_idxs] - tps
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/sklearn/utils/extmath.py in stable_cumsum(arr, axis, rtol, atol)
#     758         return np.cumsum(arr, axis=axis, dtype=np.float64)
#     759
# --> 760     out = np.cumsum(arr, axis=axis, dtype=np.float64)
#     761     expected = np.sum(arr, axis=axis, dtype=np.float64)
#     762     if not np.all(np.isclose(out.take(-1, axis=axis), expected, rtol=rtol,
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/numpy/core/fromnumeric.py in cumsum(a, axis, dtype, out)
#    2163
#    2164     """
# -> 2165     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#    2166
#    2167
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      50 def _wrapfunc(obj, method, *args, **kwds):
#      51     try:
# ---> 52         return getattr(obj, method)(*args, **kwds)
#      53
#      54     # An AttributeError occurs if the object does not have
#
# MemoryError:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f62a9fafc80> (for post_execute):
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2435             renderer.stop_rasterizing()
#    2436
# -> 2437         mimage._draw_list_compositing_images(renderer, self, artists)
#    2438
#    2439         renderer.close_group('axes')
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/collections.py in draw(self, renderer)
#     860     def draw(self, renderer):
#     861         self.set_sizes(self._sizes, self.figure.dpi)
# --> 862         Collection.draw(self, renderer)
#     863
#     864
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/collections.py in draw(self, renderer)
#     311             renderer.draw_markers(
#     312                 gc, paths[0], combined_transform.frozen(),
# --> 313                 mpath.Path(offsets), transOffset, tuple(facecolors[0]))
#     314         else:
#     315             renderer.draw_path_collection(
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw_markers(self, *kl, **kw)
#     115     # maybe there is better way to do it.
#     116     def draw_markers(self, *kl, **kw):
# --> 117         return self._renderer.draw_markers(*kl, **kw)
#     118
#     119     def draw_path_collection(self, *kl, **kw):
#
# OverflowError: In draw_markers: Exceeded cell block limit
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     164             try:
# --> 165                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     166             except OverflowError:
#
# OverflowError: In draw_path: Exceeded cell block limit
#
# During handling of the above exception, another exception occurred:
#
# OverflowError                             Traceback (most recent call last)
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             # if toolbar:
#     429             #     toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             # if toolbar:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1297
#    1298             mimage._draw_list_compositing_images(
# -> 1299                 renderer, self, artists, self.suppressComposite)
#    1300
#    1301             renderer.close_group('figure')
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2428         # will draw the edges
#    2429         if self.axison and self._frameon:
# -> 2430             self.patch.draw(renderer)
#    2431
#    2432         if artists_rasterized:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/patches.py in draw(self, renderer)
#     542             renderer = PathEffectRenderer(self.get_path_effects(), renderer)
#     543
# --> 544         renderer.draw_path(gc, tpath, affine, rgbFace)
#     545
#     546         gc.restore()
#
# ~/.local/share/virtualenvs/course_work-fzaykAtj/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     165                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     166             except OverflowError:
# --> 167                 raise OverflowError("Exceeded cell block limit (set 'agg.path.chunksize' rcparam)")
#     168
#     169
#
# OverflowError: Exceeded cell block limit (set 'agg.path.chunksize' rcparam)

# %%
trained_stack_name = 'carb96558'
predicting_stack_name = 'SPE_carb10_63_box3'
storing_path = ''.join([trained_stack_name, '_on_', predicting_stack_name, '.jbl'])
input_stack, output_stack, prediction = load(os.path.join('../output_data', storing_path))
output_stack = (output_stack.astype(np.float32) / 255).astype(np.int8)
x4, y4 = accuracy_curve(prediction, output_stack, 40)

binary = rounded = np.where(prediction > 0.1, 
                            np.ones_like(prediction, dtype=np.float32),
                            np.zeros_like(prediction, dtype=np.float32)).flatten()
p4, r4, _ = precision_recall_curve(output_stack.flatten(), prediction.flatten(), pos_label=1)

plt.step(r4, p4, color='b', alpha=0.2, where='post')
plt.fill_between(r4, p4, step='post', alpha=0.2, color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])

ap4 = average_precision_score(output_stack.flatten(), binary)
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(ap4))


print('Integrated accuracy: {}'.format(scipy.integrate.simps(y4, x4)))
print('Precission: {}'.format(precision_score(output_stack.flatten(), binary)))
print('Recall: {}'.format(precision_score(output_stack.flatten(), binary)))
print('PR-auc: {}'.format(ap4))

plt.show()

# %%
plt.figure(figsize=(10, 10))

plt.plot(x1, y1)

plt.plot(x2, y2)

plt.plot(x3, y3)

plt.plot(x4, y4)

plt.xlim([0, 1])
plt.ylim([0, 1.1])

plt.legend(['SPE_carb10_58_box3', 'carbRNF', 'carb71', 'SPE_carb10_63_box3'], fontsize=18)
plt.xlabel('Threshold', fontsize=20)
plt.ylabel('Accuracy', fontsize=20)
plt.title('Learned on carb96558 stack', fontsize=22)
plt.savefig('../output_data/example.jpg')
plt.show()

# %%
def compare(source, dest, truth, out_path, threshold=0.1):    
    misses = np.where(dest > threshold, 
                      np.ones_like(dest, dtype=np.uint8), 
                      np.zeros_like(dest, dtype=np.uint8))
    extent = 0, misses.shape[0], 0, misses.shape[1]
    
    fig = plt.figure(figsize=(25, 15))
    
    ax1 = plt.subplot(221)
    ax1.imshow(dest, cmap='gray')
    ax1.set_title('Predicted labeling', fontsize=20)
    
    ax2 = plt.subplot(222)
    ax2.imshow(truth, cmap='gray')
    ax2.set_title('True labeling', fontsize=20)
    pos = misses != truth
    
    ax3 = plt.subplot(223)
    truth = truth.reshape(truth.shape + (1, ))
    truth = np.concatenate([truth, truth, truth], axis=2)
    truth[pos] = np.array([1, 0, 0])
    ax3.imshow(truth)
    ax3.set_title('True labeling with marked difference', fontsize=20)
   
    ax4 = plt.subplot(224)
    source = source.reshape(source.shape + (1, ))
    source = np.concatenate([source, source, source], axis=2)
    source[pos] = np.array([255, 0, 0])
    ax4.imshow(source)
    ax4.set_title('Input iamge with marked difference', fontsize=20)
    plt.savefig(fname=out_path)
    plt.show()

# %%
out_path = '../output_data/check_x100.png'
compare(input_stack[600, 0:100, 0:100], prediction[600, 0:100, 0:100], output_stack[600, 0:100, 0:100], out_path)

# %%
out_path = '../output_data/check_x300.png'
compare(input_stack[300, 0:100, 0:100], prediction[300, 0:100, 0:100], output_stack[300, 0:100, 0:100], out_path)

# %%
out_path = '../output_data/check_x600.png'
compare(input_stack[600, 0:100, 0:100], prediction[600, 0:100, 0:100], output_stack[600, 0:100, 0:100], out_path)

# %%
out_path = '../output_data/check_y100.png'
compare(input_stack[:100, 100, 0:100], prediction[:100, 100, 0:100], output_stack[:100, 100, 0:100], out_path)

# %%
out_path = '../output_data/check_y300.png'
compare(input_stack[:100, 300, 0:100], prediction[:100, 300, 0:100], output_stack[:100, 300, 0:100], out_path)

# %%
out_path = '../output_data/check_y600.png'
compare(input_stack[:100, 600, 0:100], prediction[:100, 600, 0:100], output_stack[:100, 600, 0:100], out_path)

# %%
iou(prediction, output_stack, 0.1)
# Out:
# 0.990135

# %%
logloss(prediction, output_stack)
# Out:
# 0.03813749

# %%
accuracy(prediction, output_stack, 0.1)
# Out:
# 0.9913320186237558
